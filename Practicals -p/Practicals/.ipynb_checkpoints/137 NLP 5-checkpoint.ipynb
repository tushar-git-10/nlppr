# %%
# !pip install fastcoref==2.1.6
# Out:
# Requirement already satisfied: fastcoref==2.1.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (2.1.6)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (4.67.1)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (1.26.4)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (1.13.1)
# Requirement already satisfied: spacy>=3.0.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (3.8.7)
# Requirement already satisfied: torch>=1.10.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (2.8.0)
# Requirement already satisfied: transformers>=4.11.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (4.57.0)
# Requirement already satisfied: datasets>=2.5.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fastcoref==2.1.6) (4.0.0)
# Requirement already satisfied: filelock in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (3.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (0.3.8)
# Requirement already satisfied: pandas in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (2.3.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (2.32.5)
# Requirement already satisfied: xxhash in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (0.34.4)
# Requirement already satisfied: packaging in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from datasets>=2.5.2->fastcoref==2.1.6) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (3.12.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (1.20.1)
# Requirement already satisfied: idna>=2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from aiosignal>=1.4.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=2.5.2->fastcoref==2.1.6) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.32.2->datasets>=2.5.2->fastcoref==2.1.6) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.32.2->datasets>=2.5.2->fastcoref==2.1.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.32.2->datasets>=2.5.2->fastcoref==2.1.6) (2025.8.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (0.17.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (65.5.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from spacy>=3.0.6->fastcoref==2.1.6) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.0.6->fastcoref==2.1.6) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6->fastcoref==2.1.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6->fastcoref==2.1.6) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0.6->fastcoref==2.1.6) (0.4.1)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0.6->fastcoref==2.1.6) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0.6->fastcoref==2.1.6) (0.1.5)
# Requirement already satisfied: colorama in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.64.0->fastcoref==2.1.6) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0.6->fastcoref==2.1.6) (0.22.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0.6->fastcoref==2.1.6) (7.3.0.post1)
# Requirement already satisfied: wrapt in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.0.6->fastcoref==2.1.6) (1.14.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.0.6->fastcoref==2.1.6) (1.3.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0.6->fastcoref==2.1.6) (0.1.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.10.0->fastcoref==2.1.6) (1.14.0)
# Requirement already satisfied: networkx in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from torch>=1.10.0->fastcoref==2.1.6) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from sympy>=1.13.3->torch>=1.10.0->fastcoref==2.1.6) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.11.3->fastcoref==2.1.6) (2025.8.29)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.11.3->fastcoref==2.1.6) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from transformers>=4.11.3->fastcoref==2.1.6) (0.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from jinja2->spacy>=3.0.6->fastcoref==2.1.6) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets>=2.5.2->fastcoref==2.1.6) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets>=2.5.2->fastcoref==2.1.6) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from pandas->datasets>=2.5.2->fastcoref==2.1.6) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prath\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.5.2->fastcoref==2.1.6) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import warnings
warnings.filterwarnings("ignore")

from fastcoref import FCoref

# Load model
model = FCoref(device='cpu')

text = """
Rohit went to the market. He bought apples.
Later, Rohit met Suresh and he invited him for dinner.
"""

# Run prediction
preds = model.predict(texts=[text])

result = preds[0]

# Print clusters
clusters = result.get_clusters(as_strings=True)

print("Coreference Clusters:")
for cluster in clusters:
    print(cluster)

print("\nResolved Text:")

resolved_text = text

# Replace pronouns with first mention of cluster
for cluster in clusters:
    main_entity = cluster[0]   # first mention is main entity
    for mention in cluster[1:]:
        resolved_text = resolved_text.replace(mention, main_entity)

print(resolved_text)
# Out:
# 03/04/2026 23:33:14 - INFO - 	 missing_keys: []
# 03/04/2026 23:33:14 - INFO - 	 unexpected_keys: []
# 03/04/2026 23:33:14 - INFO - 	 mismatched_keys: []
# 03/04/2026 23:33:14 - INFO - 	 error_msgs: []
# 03/04/2026 23:33:14 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/04/2026 23:33:14 - INFO - 	 Tokenize 1 inputs...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# 03/04/2026 23:33:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference:   0%|          | 0/1 [00:00<?, ?it/s]
# Coreference Clusters:
# ['Rohit', 'He', 'Rohit', 'he']
# ['Suresh', 'him']
#
# Resolved Text:
#
# Rohit went to tRohit market. Rohit bought apples.
# Later, Rohit met Suresh and Rohit invited Suresh for dinner.
