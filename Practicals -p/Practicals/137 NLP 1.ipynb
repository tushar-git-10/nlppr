# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
print(para)
# Out:
# Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains.

# %% [markdown]
# ### 1.Tokenization
# ### a) Word Tokenization

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\prath\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize

# %%
for word in para:
    tokens = word_tokenize(para)

# %%
tokens
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'that',
#  'combines',
#  'computer',
#  'science',
#  ',',
#  'artificial',
#  'intelligence',
#  'and',
#  'language',
#  'studies',
#  '.',
#  'It',
#  'helps',
#  'computers',
#  'understand',
#  ',',
#  'process',
#  'and',
#  'create',
#  'human',
#  'language',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'sense',
#  'and',
#  'is',
#  'useful.It',
#  'can',
#  'use',
#  'two',
#  'domains',
#  '.']

# %% [markdown]
# ### b) Sentence Tokenizer

# %%
from nltk.tokenize import sent_tokenize
sentence = sent_tokenize(para)

# %%
sentence
# Out:
# ['Natural Language Processing is a field that combines computer science, artificial intelligence and language studies.',
#  'It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains.']

# %% [markdown]
# ### c)Punctuation Seperation Tokenizer

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(para)   ## apostrope(') also seperated and also other punctuation has sepearate token.
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'that',
#  'combines',
#  'computer',
#  'science',
#  ',',
#  'artificial',
#  'intelligence',
#  'and',
#  'language',
#  'studies',
#  '.',
#  'It',
#  'helps',
#  'computers',
#  'understand',
#  ',',
#  'process',
#  'and',
#  'create',
#  'human',
#  'language',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'sense',
#  'and',
#  'is',
#  'useful',
#  '.',
#  'It',
#  'can',
#  'use',
#  'two',
#  'domains',
#  '.']

# %% [markdown]
# ### d)TreebankTokenizer

# %%
from nltk.tokenize import TreebankWordTokenizer
word = TreebankWordTokenizer()

# %%
words=word.tokenize(para)

# %%
words
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'that',
#  'combines',
#  'computer',
#  'science',
#  ',',
#  'artificial',
#  'intelligence',
#  'and',
#  'language',
#  'studies.',
#  'It',
#  'helps',
#  'computers',
#  'understand',
#  ',',
#  'process',
#  'and',
#  'create',
#  'human',
#  'language',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'sense',
#  'and',
#  'is',
#  'useful.It',
#  'can',
#  'use',
#  'two',
#  'domains',
#  '.']

# %% [markdown]
# ### 2.Stemming

# %% [markdown]
# ### a)Porter Stemming

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for w in words:
    print(w +"------->"+ stemming.stem(w))
# Out:
# Natural------->natur
# Language------->languag
# Processing------->process
# is------->is
# a------->a
# field------->field
# that------->that
# combines------->combin
# computer------->comput
# science------->scienc
# ,------->,
# artificial------->artifici
# intelligence------->intellig
# and------->and
# language------->languag
# studies.------->studies.
# It------->it
# helps------->help
# computers------->comput
# understand------->understand
# ,------->,
# process------->process
# and------->and
# create------->creat
# human------->human
# language------->languag
# in------->in
# a------->a
# way------->way
# that------->that
# makes------->make
# sense------->sens
# and------->and
# is------->is
# useful.It------->useful.it
# can------->can
# use------->use
# two------->two
# domains------->domain
# .------->.

# %% [markdown]
# ### b)RegexpStemmer-Regular Expression Stemmer

# %%
from nltk.stem import RegexpStemmer

# %%
# Initialize RegexpStemmer to remove suffixes like 'ing', 's', 'e', 'able'

reg_stem = RegexpStemmer('ing$|s$|e$|able$')

words1 = ['eating', 'writes', 'readable', 'running']

for word1 in words1:
    print(word1 + " -> " + reg_stem.stem(word1))
# Out:
# eating -> eat
# writes -> write
# readable -> read
# running -> runn

# %% [markdown]
# ### c)Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english')

# %%
for w in words:
    print(w + " -> " + snowball_stemmer.stem(w))
# Out:
# Natural -> natur
# Language -> languag
# Processing -> process
# is -> is
# a -> a
# field -> field
# that -> that
# combines -> combin
# computer -> comput
# science -> scienc
# , -> ,
# artificial -> artifici
# intelligence -> intellig
# and -> and
# language -> languag
# studies. -> studies.
# It -> it
# helps -> help
# computers -> comput
# understand -> understand
# , -> ,
# process -> process
# and -> and
# create -> creat
# human -> human
# language -> languag
# in -> in
# a -> a
# way -> way
# that -> that
# makes -> make
# sense -> sens
# and -> and
# is -> is
# useful.It -> useful.it
# can -> can
# use -> use
# two -> two
# domains -> domain
# . -> .

# %%
snowball_stemmer.stem("fairly")
# Out:
# 'fair'

# %% [markdown]
# ### 3.Lemmatization

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemma = WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\prath\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
for w in words:
    print(w+"---->"+lemma.lemmatize(w,pos='v'))
# Out:
# Natural---->Natural
# Language---->Language
# Processing---->Processing
# is---->be
# a---->a
# field---->field
# that---->that
# combines---->combine
# computer---->computer
# science---->science
# ,---->,
# artificial---->artificial
# intelligence---->intelligence
# and---->and
# language---->language
# studies.---->studies.
# It---->It
# helps---->help
# computers---->computers
# understand---->understand
# ,---->,
# process---->process
# and---->and
# create---->create
# human---->human
# language---->language
# in---->in
# a---->a
# way---->way
# that---->that
# makes---->make
# sense---->sense
# and---->and
# is---->be
# useful.It---->useful.It
# can---->can
# use---->use
# two---->two
# domains---->domains
# .---->.

# %%
words2 = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalize"]
for word in words2:
    print(word+"---->"+lemma.lemmatize(word,pos='v'))
# Out:
# eating---->eat
# eats---->eat
# eaten---->eat
# writing---->write
# writes---->write
# programming---->program
# programs---->program
# history---->history
# finally---->finally
# finalize---->finalize

# %% [markdown]
# ### 4.Stopword Removal

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prath\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %% [markdown]
# ### a) Stemming use

# %% [markdown]
# from nltk.stem import PorterStemmer
# stemmer = PorterStemmer()

# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
sentences = nltk.sent_tokenize(para)

# %%
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [stemming.stem(word) for word in words if word.lower() not in set(stopwords.words('english'))]
    sentences[i] = " ".join(words)

# %%
sentences
# Out:
# ['natur languag process field combin comput scienc , artifici intellig languag studi .',
#  'help comput understand , process creat human languag way make sens useful.it use two domain .']

# %% [markdown]
# ### b)Lemmatization used

# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
sentences = nltk.sent_tokenize(para)

# %%
## Apply the lemmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word.lower(),pos='v') for word in words if word.lower() not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
sentences
# Out:
# ['natural language process field combine computer science , artificial intelligence language study .',
#  'help computers understand , process create human language way make sense useful.it use two domains .']

# %% [markdown]
# ### 5.Uppercase and Lowercase

# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
words = nltk.word_tokenize(para)

# %%
for word in words:
    print(word+"==========>"+word.lower())
# Out:
# Natural==========>natural
# Language==========>language
# Processing==========>processing
# is==========>is
# a==========>a
# field==========>field
# that==========>that
# combines==========>combines
# computer==========>computer
# science==========>science
# ,==========>,
# artificial==========>artificial
# intelligence==========>intelligence
# and==========>and
# language==========>language
# studies==========>studies
# .==========>.
# It==========>it
# helps==========>helps
# computers==========>computers
# understand==========>understand
# ,==========>,
# process==========>process
# and==========>and
# create==========>create
# human==========>human
# language==========>language
# in==========>in
# a==========>a
# way==========>way
# that==========>that
# makes==========>makes
# sense==========>sense
# and==========>and
# is==========>is
# useful.It==========>useful.it
# can==========>can
# use==========>use
# two==========>two
# domains==========>domains
# .==========>.

# %%
for word in words:
    print(word+"==========>"+word.upper())
# Out:
# Natural==========>NATURAL
# Language==========>LANGUAGE
# Processing==========>PROCESSING
# is==========>IS
# a==========>A
# field==========>FIELD
# that==========>THAT
# combines==========>COMBINES
# computer==========>COMPUTER
# science==========>SCIENCE
# ,==========>,
# artificial==========>ARTIFICIAL
# intelligence==========>INTELLIGENCE
# and==========>AND
# language==========>LANGUAGE
# studies==========>STUDIES
# .==========>.
# It==========>IT
# helps==========>HELPS
# computers==========>COMPUTERS
# understand==========>UNDERSTAND
# ,==========>,
# process==========>PROCESS
# and==========>AND
# create==========>CREATE
# human==========>HUMAN
# language==========>LANGUAGE
# in==========>IN
# a==========>A
# way==========>WAY
# that==========>THAT
# makes==========>MAKES
# sense==========>SENSE
# and==========>AND
# is==========>IS
# useful.It==========>USEFUL.IT
# can==========>CAN
# use==========>USE
# two==========>TWO
# domains==========>DOMAINS
# .==========>.

# %% [markdown]
# #### 6.Number to text conversion

# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
import re
from num2words import num2words

def convert_numbers_to_words(text):
    return re.sub(r'\d+', lambda x: num2words(int(x.group())), text)

result = convert_numbers_to_words(para)
print(result)
# Out:
# Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains.

# %% [markdown]
# ## Without Library ( Number to Words)

# %%
para ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use 2 domains."
num_dict = {
    '0': 'zero', '1': 'one', '2': 'two', '3': 'three',
    '4': 'four', '5': 'five', '6': 'six',
    '7': 'seven', '8': 'eight', '9': 'nine'
}

def num_to_words_simple(text):
    for digit, word in num_dict.items():
        text = text.replace(digit, word)
    return text

print(num_to_words_simple(para))
# Out:
# Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains.

# %% [markdown]
# ## Without Library ( words to number)

# %%
word_to_num = {
    "one": "1",
    "two": "2",
    "three": "3",
    "four": "4",
    "five": "5"
}

def simple_word_to_num(text):
    for word, num in word_to_num.items():
        text = re.sub(rf'\b{word}\b', num, text, flags=re.IGNORECASE)
    return text

print(simple_word_to_num(para))
# Out:
# Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use 2 domains.
