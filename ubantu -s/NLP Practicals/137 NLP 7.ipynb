# %% [markdown]
# #### Title : Word embedding: Implement word embeddings for the English language to analyze word
# #### representations and their semantic relationships (Word2Vec/GloVe/fastText).
#
# #### Name : Wavhal Prathmesh Navnath
# #### Roll No : 23107137
# #### Class : TY-B
# #### Batch : C

# %%
# Loading dataset
import json

file_path = "../admin1/Downloads/Cell_Phones_and_Accessories_5.json"

data = []

with open(file_path, "r", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line))
print("Dataset :", len(data))
# Out:
# Dataset : 194439

# %%
# Preprocessing
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

def preprocess(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    words = word_tokenize(text)
    return [w for w in words if w not in stop_words]

tokenized_sentences = [preprocess(s) for s in sentences if len(s) > 0]
# Out:
# [nltk_data] Downloading package punkt to /home/admin1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/admin1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# model Word2vec
from gensim.models import Word2Vec

model = Word2Vec(
    sentences=tokenized_sentences,
    vector_size=100,
    window=5,
    min_count=5
)

# %%
output = model.wv.most_similar("movie")

for word, score in output:
    print(word, score)
# Out:
# movies 0.8904291391372681
# netflix 0.8885560035705566
# watching 0.7751959562301636
# videos 0.7607958316802979
# television 0.7480012774467468
# hulu 0.7455626726150513
# videosmovies 0.7434024810791016
# moviesvideos 0.7196531295776367
# watch 0.7104024887084961
# game 0.7028312087059021

# %%
model.wv.similarity("movie","movies")
# Out:
# 0.8904292

# %%
# model Fast - texting
from gensim.models import FastText

fasttext_model = FastText(
    sentences=tokenized_sentences,
    vector_size=100,
    window=5,
    min_count=5
)

# %%
output = fasttext_model.wv.most_similar("movie","movies")

for word, score in output:
    print(word, score)
# Out:
# jie 0.7802646160125732
# eie 0.7682747840881348
# kadie 0.7503737211227417
# odie 0.7476625442504883
# mcjazzie 0.7297108769416809
# kaytie 0.7282674312591553
# zuggie 0.7265968918800354
# tuynie 0.7245789170265198
# jimmie 0.7218682765960693
# krykie 0.7195819020271301

# %%
model.wv.similarity("movie","movies")
# Out:
# 0.8904292
