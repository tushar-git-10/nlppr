# %%
import nltk

# %%
import re

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.tokenize import sent_tokenize

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
text ="Natural Language Processing is a field that combines computer science, artificial intelligence and language studies. It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains."

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\kokar\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Lowercase
text_lower = text.lower()

# Remove punctuation
clean_text = re.sub(r'[^a-z\s]', '', text_lower)

# %%
sentence  = sent_tokenize(text)

# %%
sentence
# Out:
# ['Natural Language Processing is a field that combines computer science, artificial intelligence and language studies.',
#  'It helps computers understand, process and create human language in a way that makes sense and is useful.It can use two domains.']

# %%
word = word_tokenize(text)

# %%
word
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'that',
#  'combines',
#  'computer',
#  'science',
#  ',',
#  'artificial',
#  'intelligence',
#  'and',
#  'language',
#  'studies',
#  '.',
#  'It',
#  'helps',
#  'computers',
#  'understand',
#  ',',
#  'process',
#  'and',
#  'create',
#  'human',
#  'language',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'sense',
#  'and',
#  'is',
#  'useful.It',
#  'can',
#  'use',
#  'two',
#  'domains',
#  '.']

# %%
pun = wordpunct_tokenize(text)

# %%
pun
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'that',
#  'combines',
#  'computer',
#  'science',
#  ',',
#  'artificial',
#  'intelligence',
#  'and',
#  'language',
#  'studies',
#  '.',
#  'It',
#  'helps',
#  'computers',
#  'understand',
#  ',',
#  'process',
#  'and',
#  'create',
#  'human',
#  'language',
#  'in',
#  'a',
#  'way',
#  'that',
#  'makes',
#  'sense',
#  'and',
#  'is',
#  'useful',
#  '.',
#  'It',
#  'can',
#  'use',
#  'two',
#  'domains',
#  '.']
