# %%
# Text Mining: Sentiment Analysis + Keyword Extraction

import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# Download once
nltk.download('vader_lexicon')

# Sample customer reviews
reviews = [
    "This product is amazing and works perfectly",
    "Very bad experience, waste of money",
    "It is okay, not great but not bad",
    "Excellent quality and fast delivery",
    "Terrible product, I hate it"
]

# Sentiment Analyzer
sia = SentimentIntensityAnalyzer()

print("Sentiment Analysis:\n")
for review in reviews:
    score = sia.polarity_scores(review)['compound']
    
    if score > 0:
        sentiment = "Positive"
    elif score < 0:
        sentiment = "Negative"
    else:
        sentiment = "Neutral"
    
    print(f"Review: {review}")
    print(f"Sentiment: {sentiment}\n")

# Keyword Extraction
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(reviews)

keywords = vectorizer.get_feature_names_out()

print("Top Keywords:")
print(keywords[:10])
# Out:
# Sentiment Analysis:
#
# Review: This product is amazing and works perfectly
# Sentiment: Positive
#
# Review: Very bad experience, waste of money
# Sentiment: Negative
#
# Review: It is okay, not great but not bad
# Sentiment: Positive
#
# Review: Excellent quality and fast delivery
# Sentiment: Positive
#
# Review: Terrible product, I hate it
# Sentiment: Negative
#
# Top Keywords:
# ['amazing' 'bad' 'delivery' 'excellent' 'experience' 'fast' 'great' 'hate'
#  'money' 'okay']
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\kokar\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
